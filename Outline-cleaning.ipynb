# %%
import numpy as np
import pandas as pd
# %matplotlib inline
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('numbers_outline.csv')

# %%
df
# Out:
#     Values
# 0        5
# 1        5
# 2       50
# 3       50
# 4       50
# 5       50
# 6       50
# 7       50
# 8       50
# 9       50
# 10      50
# 11      50
# 12      50
# 13      50
# 14      50
# 15      50
# 16      50
# 17      50
# 18      50
# 19      50
# 20      50
# 21      50
# 22      50
# 23      50
# 24      50
# 25      50
# 26      50
# 27      50
# 28      50
# 29      50
# 30      50
# 31      50
# 32      50
# 33      50
# 34      50
# 35      50
# 36     100
# 37     100

# %%
plt.hist(df)
# Out:
# <img src="data:image/png;base64,..." width="432">
# (array([ 2.,  0.,  0.,  0., 34.,  0.,  0.,  0.,  0.,  2.]),
#  array([  5. ,  14.5,  24. ,  33.5,  43. ,  52.5,  62. ,  71.5,  81. ,
#          90.5, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
lower_bound = 0.05
upper_bound = 0.96
res = df['Values'].quantile([lower_bound,upper_bound])

# %%
res
# Out:
# 0.05    43.25
# 0.96    76.00
# Name: Values, dtype: float64

# %%
true_index = (res.loc[lower_bound]<df.Values.values) & (res.loc[upper_bound]>df.Values.values)

# %%
true_index
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False])

# %%
false_index =  true_index != True

# %%
false_index
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True])

# %%
df.Values[true_index]
# Out:
# 2     50
# 3     50
# 4     50
# 5     50
# 6     50
# 7     50
# 8     50
# 9     50
# 10    50
# 11    50
# 12    50
# 13    50
# 14    50
# 15    50
# 16    50
# 17    50
# 18    50
# 19    50
# 20    50
# 21    50
# 22    50
# 23    50
# 24    50
# 25    50
# 26    50
# 27    50
# 28    50
# 29    50
# 30    50
# 31    50
# 32    50
# 33    50
# 34    50
# 35    50
# Name: Values, dtype: int64

# %%
df.Values[false_index]
# Out:
# 0       5
# 1       5
# 36    100
# 37    100
# Name: Values, dtype: int64

# %%
np.median(df.Values)
# Out:
# 50.0

# %%
df.Values[false_index] = np.median(df.Values)

# %%
df
# Out:
#     Values
# 0       50
# 1       50
# 2       50
# 3       50
# 4       50
# 5       50
# 6       50
# 7       50
# 8       50
# 9       50
# 10      50
# 11      50
# 12      50
# 13      50
# 14      50
# 15      50
# 16      50
# 17      50
# 18      50
# 19      50
# 20      50
# 21      50
# 22      50
# 23      50
# 24      50
# 25      50
# 26      50
# 27      50
# 28      50
# 29      50
# 30      50
# 31      50
# 32      50
# 33      50
# 34      50
# 35      50
# 36      50
# 37      50

# %%
plt.hist(df)
# Out:
# <img src="data:image/png;base64,..." width="432">
# (array([ 0.,  0.,  0.,  0.,  0., 38.,  0.,  0.,  0.,  0.]),
#  array([49.5, 49.6, 49.7, 49.8, 49.9, 50. , 50.1, 50.2, 50.3, 50.4, 50.5]),
#  <BarContainer object of 10 artists>)

# %%
df.to_csv('outline_removed.csv')
